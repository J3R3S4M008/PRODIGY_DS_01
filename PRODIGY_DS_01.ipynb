# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv(r"C:\Users\ASUS\Desktop\Intern\prodigy\Salary_Data.csv")

# %%
# Histogram for Age
plt.figure(figsize=(6,4))
sns.histplot(data['Age'].dropna(), bins=30, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram for Years of Experience
plt.figure(figsize=(6,4))
sns.histplot(data['Years of Experience'].dropna(), bins=30, kde=True)
plt.title('Distribution of Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar Chart for Gender
plt.figure(figsize=(6,4))
sns.countplot(data=data, x='Gender')
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Bar Chart for Education Level
plt.figure(figsize=(10,4))
sns.countplot(data=data, x='Education Level', order=data['Education Level'].value_counts().index)
plt.title('Distribution of Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
